# %% [markdown]
# # **PANDAS MINI PROJECT**

# %% [markdown]
# You are a data analyst at a university tasked with analyzing the grades of students in a course. Your goal is to provide insights into the performance of students, identify patterns, and make recommendations for improving student outcomes. You will use Python, Pandas, and Numpy to load, clean, and analyze the data where appropriate

# %%
#load the libraries
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#load the roster file and display first 5 rows
roster=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/roster - roster.csv")
roster.head()
# Out:
#         ID                    Name     NetID              Email Address  \
# 0  1234567      Barrera Jr., Woody  WXB12345  WOODY.BARRERA_JR@UNIV.EDU
# 1  2345678        Lambert, Malaika  MXL12345   MALAIKA.LAMBERT@UNIV.EDU
# 2  3456789            Joyce, Traci  TXJ12345       TRACI.JOYCE@UNIV.EDU
# 3  4567890      Flower, John Gregg  JGF12345   JOHN.G.2.FLOWER@UNIV.EDU
# 4  8406082  Johnson, Stacy Michael  SMJ00936     STACY.JOHNSON@UNIV.EDU
#
#    Section
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2

# %% [markdown]
# Eh? This is not the data that we want :( We want to have it more modified.

# %% [markdown]
#   We want the 'roster' to be something else! How though:
#
#   We want **NetID**, **Email Address** and **Section** but somehow different:
#
#   1. NetID: make the each string in lowercase and have it set as an index.
#   2. Email Address: have the string in lowercase
#
#   and after that, have these 3 columns display in a dataframe.

# %%
roster.columns
# Out:
# Index(['ID', 'Name', 'NetID', 'Email Address', 'Section'], dtype='object')

# %%
#data pre-processing
df=roster[["NetID",'Email Address', 'Section']]
df["Email Address"]=df["Email Address"].str.lower()
df["NetID"]=df["NetID"].str.lower()
df.set_index("NetID", inplace=True)
df.head()
# Out:
# <ipython-input-113-def82821c044>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Email Address"]=df["Email Address"].str.lower()
# <ipython-input-113-def82821c044>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NetID"]=df["NetID"].str.lower()
#                       Email Address  Section
# NetID
# wxb12345  woody.barrera_jr@univ.edu        1
# mxl12345   malaika.lambert@univ.edu        2
# txj12345       traci.joyce@univ.edu        1
# ...

# %% [markdown]
# ### **Load the homework and exam data**

# %%
#load the hw_exam_grades and display first 5 rows
hw_exam_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/hw_exam_grades.csv")
hw_exam_grades.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# ...

# %% [markdown]
# The data is not cleaned. We also want to do something different to it.
#
# We want the data to be indexed on the basis of SID and remove all the columns which has the word 'Submission' in it using lambda filter.

# %%
#if you attempt to remove the submissional columns without lambda filter, points will be deducted accordingly.
# hw_exam_grades.set_index("SID", inplace=True)
hw_exam_grades.drop(columns=hw_exam_grades.columns[hw_exam_grades.columns.str.contains("Submission")], inplace=True)
hw_exam_grades.head()
# Out:
#          First Name  Last Name  Homework 1  Homework 1 - Max Points  \
# SID
# axl60952      Aaron     Lester        68.0                       80
# amc28428       Adam     Cooper        80.0                       80
# axc64717       Alec      Curry        69.0                       80
# akr14831  Alexander  Rodriguez        50.0                       80
# axd11293      Amber    Daniels        54.0                       80
#
#           Homework 2  Homework 2 - Max Points  Homework 3  \
# SID
# axl60952          74                       80          77
# amc28428          78                       80          78
# axc64717          76                       80          66
# akr14831          54                       80          74
# axd11293          57                       80          77
#
#           Homework 3 - Max Points  Homework 4  Homework 4 - Max Points  ...  \
# SID                                                                     ...
# ...

# %% [markdown]
# ### **Load the Quiz Files**

# %% [markdown]
# Load quiz grades (quiz_1_grades.csv, ..., quiz_5_grades.csv)

# %%
#load all the quizzes now, but i want it the dataframe to be indexed on emails, and return all quizzes corresponding to that email.
#for the expected output of this code, refer to the submissional pdf shared with you in whatsapp group.
quiz_1_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv")
quiz_2_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv")
quiz_3_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv")
quiz_4_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv")
quiz_5_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv")
quiz_1_grades.sort_values(by="Email", inplace=True)
quiz_1_grades.set_index("Email", inplace=True)
for i in [quiz_2_grades, quiz_3_grades, quiz_4_grades, quiz_5_grades]:
  i.sort_values(by="Email", inplace=True)
  i.set_index("Email", inplace=True)
  i.drop(columns=i.columns[i.columns != "Grade"],inplace=True)
  pd.merge(quiz_1_grades, i)

# %%
import pandas as pd

# Load the two DataFrames
quiz_1_grades = pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv")
quiz_2_grades = pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv")
quiz_3_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv")
quiz_4_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv")
quiz_5_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv")

# Sort by Email and set as index
quiz_1_grades.sort_values(by="Email", inplace=True)
quiz_1_grades.set_index("Email", inplace=True)

quiz_2_grades.sort_values(by="Email", inplace=True)
quiz_2_grades.set_index("Email", inplace=True)

quiz_3_grades.sort_values(by="Email", inplace=True)
quiz_3_grades.set_index("Email", inplace=True)

quiz_4_grades.sort_values(by="Email", inplace=True)
quiz_4_grades.set_index("Email", inplace=True)

quiz_5_grades.sort_values(by="Email", inplace=True)
quiz_5_grades.set_index("Email", inplace=True)
# Select only the "Shape" column from quiz_2_grades
quiz_2_shape = quiz_2_grades[["Grade"]]
quiz_3_shape = quiz_3_grades[["Grade"]]
quiz_4_shape = quiz_4_grades[["Grade"]]
quiz_5_shape = quiz_5_grades[["Grade"]]

quiz_2_shape.rename(columns={"Grade":"Grade2"}, inplace=True)
quiz_3_shape.rename(columns={"Grade":"Grade3"}, inplace=True)
quiz_4_shape.rename(columns={"Grade":"Grade4"}, inplace=True)
quiz_5_shape.rename(columns={"Grade":"Grade5"}, inplace=True)
# Merge the two DataFrames
result = pd.merge(quiz_1_grades, quiz_2_shape, left_index=True, right_index=True, how="inner")
result = pd.merge(result, quiz_3_shape, left_index=True, right_index=True, how="inner")
result = pd.merge(result, quiz_4_shape, left_index=True, right_index=True, how="inner")
result = pd.merge(result, quiz_5_shape, left_index=True, right_index=True, how="inner")
# Display the resulting DataFrame
result
# Out:
# <ipython-input-95-965dde688159>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quiz_2_shape.rename(columns={"Grade":"Grade2"}, inplace=True)
# <ipython-input-95-965dde688159>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quiz_3_shape.rename(columns={"Grade":"Grade3"}, inplace=True)
# <ipython-input-95-965dde688159>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import pandas as pd

# File paths for all quizzes
quiz_files = [
    "/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv",
    "/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv",
    "/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv",
    "/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv",
    "/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv"
]

# Initialize the main DataFrame with the first quiz
main_df = pd.read_csv(quiz_files[0])
main_df.sort_values(by="Email", inplace=True)
main_df.set_index("Email", inplace=True)

# Rename the "Grade" column of the first quiz
main_df.rename(columns={"Grade": "Grade1"}, inplace=True)

# Loop through the rest of the quiz files
for i, file_path in enumerate(quiz_files[1:], start=2):
    # Read each quiz file
    quiz_df = pd.read_csv(file_path)

    # Sort by Email and set Email as index
    quiz_df.sort_values(by="Email", inplace=True)
    quiz_df.set_index("Email", inplace=True)

    # Keep only the "Grade" column and rename it
    quiz_df = quiz_df[["Grade"]]
    quiz_df.rename(columns={"Grade": f"Grade{i}"}, inplace=True)

    # Merge with the main DataFrame
    main_df = pd.merge(main_df, quiz_df, left_index=True, right_index=True, how="inner")

# Display the resulting DataFrame
main_df.head()
# Out:
#                               Last Name First Name  Grade1  Grade2  Grade3  \
# Email
# aaron.lester@univ.edu            Lester      Aaron       6       9      10
# adam.cooper@univ.edu             Cooper       Adam       4      10      16
# alec.curry@univ.edu               Curry       Alec       9       9       9
# alexander.rodriguez@univ.edu  Rodriguez  Alexander      11      13      16
# amber.daniels@univ.edu          Daniels      Amber       7      15      16
#
#                               Grade4  Grade5
# Email
# aaron.lester@univ.edu              8       8
# adam.cooper@univ.edu               7      12
# alec.curry@univ.edu               12      11
# alexander.rodriguez@univ.edu      11       7
# amber.daniels@univ.edu             5       6

# %% [markdown]
# Now, join the roster and the hw_exam_grades and store it in a df named
# '**final_df**' display first 5 rows.

# %%
final_df=pd.merge(df,hw_exam_grades,left_on="NetID",right_on="SID",how="inner")
final_df
# Out:
#                  Email Address  Section First Name Last Name  Homework 1  \
# 0    woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# 1     malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# 2         traci.joyce@univ.edu        1      Traci     Joyce         NaN
# 3     john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# 4       stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
# ..                         ...      ...        ...       ...         ...
# 145      paul.johnson@univ.edu        3       Paul   Johnson        73.0
# 146      danielle.lee@univ.edu        3   Danielle       Lee        69.0
# 147    nicole.edwards@univ.edu        3     Nicole   Edwards        62.0
# 148      bailey.reyes@univ.edu        2     Bailey     Reyes        53.0
# 149       joyce.walls@univ.edu        1      Joyce     Walls        59.0
#
#      Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  Homework 3  \
# ...

# %% [markdown]
# Also, display quiz **columns** and **indexes** in two seperate code blocks to make sure you get the sense of the data.

# %%
final_df.columns
# Out:
# Index(['Email Address', 'Section', 'First Name', 'Last Name', 'Homework 1',
#        'Homework 1 - Max Points', 'Homework 2', 'Homework 2 - Max Points',
#        'Homework 3', 'Homework 3 - Max Points', 'Homework 4',
#        'Homework 4 - Max Points', 'Homework 5', 'Homework 5 - Max Points',
#        'Homework 6', 'Homework 6 - Max Points', 'Homework 7',
#        'Homework 7 - Max Points', 'Homework 8', 'Homework 8 - Max Points',
#        'Homework 9', 'Homework 9 - Max Points', 'Homework 10',
#        'Homework 10 - Max Points', 'Exam 1', 'Exam 1 - Max Points', 'Exam 2',
#        'Exam 2 - Max Points', 'Exam 3', 'Exam 3 - Max Points'],
#       dtype='object')

# %% [markdown]
# ### **Merging the Grade DataFrame**

# %%
#now merge the final_df and quiz grades, on EMAIL ADDRESS and overwrite it in final_df variable
final_df=final_df.merge(result,how="outer",left_on="Email Address",right_on="Email")
#fill empty values with 0 as well
final_df.fillna(0)
final_df
# Out:
#                     Email Address  Section First Name_x Last Name_x  \
# 0           aaron.lester@univ.edu        2        Aaron      Lester
# 1            adam.cooper@univ.edu        2         Adam      Cooper
# 2             alec.curry@univ.edu        2         Alec       Curry
# 3    alexander.rodriguez@univ.edu        2    Alexander   Rodriguez
# 4          amber.daniels@univ.edu        2        Amber     Daniels
# ..                            ...      ...          ...         ...
# 145    travis.washington@univ.edu        1       Travis  Washington
# 146         troy.raymond@univ.edu        3         Troy     Raymond
# 147        victoria.boyd@univ.edu        2     Victoria        Boyd
# 148       william.daniel@univ.edu        2      William      Daniel
# 149     woody.barrera_jr@univ.edu        1        Woody     Barrera
#
#      Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# ...

# %% [markdown]
# ### **Calculate Grades with Pandas DataFrame**

# %% [markdown]
# ### Exam Grades

# %% [markdown]
# Now, I want you to calculate the percentage of all 3 exams and then have it display at the end of the final_df

# %%
#to find the percentage:   Exam 1 / Exam 1 max points.
#Hint: you can use fstrings and loops for it
per_exam_1=final_df["Homework 1"]/final_df["Homework 1 - Max Points"]*100
per_exam_2=final_df["Homework 2"]/final_df["Homework 2 - Max Points"]*100
per_exam_3=final_df["Homework 3"]/final_df["Homework 3 - Max Points"]*100

# %% [markdown]
# ### Homework Grades

# %% [markdown]
# **Question 1: Identifying Homework Columns**

# %%
#Identify and separate the columns representing homework scores and their respective maximum points.
columns=final_df.columns[final_df.columns.str.contains("Homework")]

# %%
scores_df=final_df[columns]
scores_df.shape
# Out:
# (150, 20)

# %% [markdown]
# **Question 2: Calculating Homework Score by Total Method**

# %%
#Calculate the homework scores by summing the actual scores and dividing by the total possible points.
homework_max_scores=scores_df.iloc[:,1::2]
homework_scores=scores_df.iloc[:,0::2]
#IT is the average scores of each student but we can find total scores by only getting sum and not dividing them with total
total_homework_scores=scores_df.iloc[:,0::2].sum(axis=1)

# %% [markdown]
# **Question 3: Storing Homework Score by Total Method**

# %%
#Add the calculated total homework scores to the DataFrame.
final_df["Total Homework Score"]=total_homework_scores

# %% [markdown]
# **Question 4: Preparing Data for Average Calculation**

# %%
#Prepare the maximum points data to align with the actual scores for element-wise division.
final_df
# Out:
#                     Email Address  Section First Name_x Last Name_x  \
# 0           aaron.lester@univ.edu        2        Aaron      Lester
# 1            adam.cooper@univ.edu        2         Adam      Cooper
# 2             alec.curry@univ.edu        2         Alec       Curry
# 3    alexander.rodriguez@univ.edu        2    Alexander   Rodriguez
# 4          amber.daniels@univ.edu        2        Amber     Daniels
# ..                            ...      ...          ...         ...
# 145    travis.washington@univ.edu        1       Travis  Washington
# 146         troy.raymond@univ.edu        3         Troy     Raymond
# 147        victoria.boyd@univ.edu        2     Victoria        Boyd
# 148       william.daniel@univ.edu        2      William      Daniel
# 149     woody.barrera_jr@univ.edu        1        Woody     Barrera
#
#      Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# ...

# %% [markdown]
# **Question 5: Calculating Homework Score by Average Method**

# %%
#Calculate the average homework scores by dividing each actual score by its corresponding maximum points, summing these ratios, and then dividing by the number of assignments.
avg_scores=(homework_scores.values/homework_max_scores.values).sum(axis=1)/homework_scores.shape[1]
final_df["Average Homework Score"]=avg_scores

# %% [markdown]
# **Question 6: Storing Homework Score by Average Method**

# %%
#Add the calculated average homework scores to the DataFrame.
final_df
# Out:
#                     Email Address  Section First Name_x Last Name_x  \
# 0           aaron.lester@univ.edu        2        Aaron      Lester
# 1            adam.cooper@univ.edu        2         Adam      Cooper
# 2             alec.curry@univ.edu        2         Alec       Curry
# 3    alexander.rodriguez@univ.edu        2    Alexander   Rodriguez
# 4          amber.daniels@univ.edu        2        Amber     Daniels
# ..                            ...      ...          ...         ...
# 145    travis.washington@univ.edu        1       Travis  Washington
# 146         troy.raymond@univ.edu        3         Troy     Raymond
# 147        victoria.boyd@univ.edu        2     Victoria        Boyd
# 148       william.daniel@univ.edu        2      William      Daniel
# 149     woody.barrera_jr@univ.edu        1        Woody     Barrera
#
#      Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# ...

# %% [markdown]
# **Question 7: Determining the Final Homework Score**

# %%
#Determine the final homework score for each student by taking the maximum value between the total and average methods.
final_df["Homework Score"]=final_df[["Total Homework Score","Average Homework Score"]].max(axis=1)

# %%
final_df
# Out:
#                     Email Address  Section First Name_x Last Name_x  \
# 0           aaron.lester@univ.edu        2        Aaron      Lester
# 1            adam.cooper@univ.edu        2         Adam      Cooper
# 2             alec.curry@univ.edu        2         Alec       Curry
# 3    alexander.rodriguez@univ.edu        2    Alexander   Rodriguez
# 4          amber.daniels@univ.edu        2        Amber     Daniels
# ..                            ...      ...          ...         ...
# 145    travis.washington@univ.edu        1       Travis  Washington
# 146         troy.raymond@univ.edu        3         Troy     Raymond
# 147        victoria.boyd@univ.edu        2     Victoria        Boyd
# 148       william.daniel@univ.edu        2      William      Daniel
# 149     woody.barrera_jr@univ.edu        1        Woody     Barrera
#
#      Homework 1  Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# ...

# %% [markdown]
# For the output, you may refer to the output refered in the Submission Book.

# %% [markdown]
# ## Quiz Grades
#
# If you used any other method instead of regex to filter the columns, it will result in appropriate points deduction.

# %%
#Filter the columns representing quiz scores using regex
import re
quiz_columns=[col for col in final_df.columns if re.match(r"Grade",col)]
quizzes=final_df[quiz_columns]

# %% [markdown]
# 1. Count the number of quizzes.
# 2. Define the maximum possible points for each quiz.
# 3. Compute the quiz score using the total method.
# 4. Compute the quiz score using the average method.
# 5. Determine the final quiz score by taking the maximum of the two methods.
# 6. Display the DataFrame to check the results

# %%
print(quizzes.shape[1])
print(quizzes.max(axis=0))
print(quizzes.sum(axis=1))
print(quizzes.sum(axis=1)/quizzes.shape[1])
print(np.maximum(quizzes.sum(axis=1),quizzes.sum(axis=1)/quizzes.shape[1]))
# Out:
# 5
# Grade     11
# Grade2    15
# Grade3    17
# Grade4    14
# Grade5    12
# dtype: int64
# 0      41
# 1      49
# 2      50
# 3      58
# 4      49
#        ..
# 145    51
# 146    40
# 147    37
# 148    43
# 149    42
# Length: 150, dtype: int64
# 0       8.2
# 1       9.8
# 2      10.0
# 3      11.6
# 4       9.8
#        ...
# 145    10.2
# 146     8.0
# 147     7.4
# 148     8.6
# 149     8.4
# Length: 150, dtype: float64
# 0      41.0
# 1      49.0
# 2      50.0
# 3      58.0
# 4      49.0
#        ...
# 145    51.0
# 146    40.0
# 147    37.0
# 148    43.0
# 149    42.0
# Length: 150, dtype: float64

# %%
#Expected Output: The DataFrame should contain an additional column 'Quiz Score' showing the final quiz score for each student, calculated as the maximum value between the total and average methods.

# %% [markdown]
# ## Group the data to calculate final scores!

# %%
weights = pd.Series(
    {
        "Exam 1 Score": 0.05,
        "Exam 2 Score": 0.10,
        "Exam 3 Score": 0.15,
        "Quiz Score": 0.30,
        "Homework Score": 0.40,
    }
)

# %% [markdown]
# 1. Define the weights for each component.
# 2. Calculate the final score by applying the weights to each component and summing the results.
# 3. Calculate the ceiling score by rounding up the final score multiplied by 100.
# 4. Define a function to convert numeric scores to letter grades based on standard thresholds.
# 5. Map the ceiling scores to letter grades.
# 6. Store the letter grades as a categorical column in the DataFrame.
# 7. Display the final letter grades.

# %%
#For Expected output, refer to the submissional pdf.

# %% [markdown]
# ### Now, you have to write the data back to CSV.

# %%
#For the expected output, refer to the submissional pdf.
