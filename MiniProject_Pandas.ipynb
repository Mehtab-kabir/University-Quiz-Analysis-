# %% [markdown]
# # **PANDAS MINI PROJECT**

# %% [markdown]
# You are a data analyst at a university tasked with analyzing the grades of students in a course. Your goal is to provide insights into the performance of students, identify patterns, and make recommendations for improving student outcomes. You will use Python, Pandas, and Numpy to load, clean, and analyze the data where appropriate

# %%
#load the libraries
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#load the roster file and display first 5 rows
roster=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/roster - roster.csv")
roster.head()
# Out:
#         ID                    Name     NetID              Email Address  \
# 0  1234567      Barrera Jr., Woody  WXB12345  WOODY.BARRERA_JR@UNIV.EDU
# 1  2345678        Lambert, Malaika  MXL12345   MALAIKA.LAMBERT@UNIV.EDU
# 2  3456789            Joyce, Traci  TXJ12345       TRACI.JOYCE@UNIV.EDU
# 3  4567890      Flower, John Gregg  JGF12345   JOHN.G.2.FLOWER@UNIV.EDU
# 4  8406082  Johnson, Stacy Michael  SMJ00936     STACY.JOHNSON@UNIV.EDU
#
#    Section
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2

# %% [markdown]
# Eh? This is not the data that we want :( We want to have it more modified.

# %% [markdown]
#   We want the 'roster' to be something else! How though:
#
#   We want **NetID**, **Email Address** and **Section** but somehow different:
#
#   1. NetID: make the each string in lowercase and have it set as an index.
#   2. Email Address: have the string in lowercase
#
#   and after that, have these 3 columns display in a dataframe.

# %%
#data pre-processing
roster['NetID'] = roster['NetID'].str.lower()
roster['Email Address'] = roster['Email Address'].str.lower()

roster.set_index('NetID', inplace=True)

new_roaster =  roster[['Email Address', 'Section']]

new_roaster.head()
# Out:
#                       Email Address  Section
# NetID
# wxb12345  woody.barrera_jr@univ.edu        1
# mxl12345   malaika.lambert@univ.edu        2
# txj12345       traci.joyce@univ.edu        1
# jgf12345   john.g.2.flower@univ.edu        3
# smj00936     stacy.johnson@univ.edu        2

# %% [markdown]
# ### **Load the homework and exam data**

# %%
#load the hw_exam_grades and display first 5 rows
hw_exam_grades=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/hw_exam_grades.csv")
hw_exam_grades.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# 1    2019-09-05 08:56:02-07:00          78  ...
# 2    2019-09-05 08:56:02-07:00          66  ...
# 3    2019-09-05 08:56:02-07:00          74  ...
# 4    2019-09-05 08:56:02-07:00          77  ...
#
#    Homework 10 - Submission Time Exam 1  Exam 1 - Max Points  \
# 0      2019-10-31 08:56:02-07:00     79                  100
# 1      2019-10-31 08:56:02-07:00     65                  100
# 2      2019-10-31 08:56:02-07:00     65                  100
# 3      2019-10-31 08:56:02-07:00     97                  100
# 4      2019-10-31 08:56:02-07:00     68                  100
#
#     Exam 1 - Submission Time Exam 2  Exam 2 - Max Points  \
# 0  2019-10-08 12:30:07-07:00     63                  100
# 1  2019-10-08 12:30:07-07:00     63                  100
# 2  2019-10-08 12:30:07-07:00     78                  100
# 3  2019-10-08 12:30:07-07:00     97                  100
# 4  2019-10-08 12:30:07-07:00     95                  100
#
#     Exam 2 - Submission Time Exam 3  Exam 3 - Max Points  \
# 0  2019-11-08 12:30:07-07:00     68                  100
# 1  2019-11-08 12:30:07-07:00     90                  100
# 2  2019-11-08 12:30:07-07:00     83                  100
# 3  2019-11-08 12:30:07-07:00     81                  100
# 4  2019-11-08 12:30:07-07:00     88                  100
#
#     Exam 3 - Submission Time
# 0  2019-12-08 12:30:07-07:00
# 1  2019-12-08 12:30:07-07:00
# 2  2019-12-08 12:30:07-07:00
# 3  2019-12-08 12:30:07-07:00
# 4  2019-12-08 12:30:07-07:00
#
# [5 rows x 42 columns]

# %% [markdown]
# The data is not cleaned. We also want to do something different to it.
#
# We want the data to be indexed on the basis of SID and remove all the columns which has the word 'Submission' in it using lambda filter.

# %%
#if you attempt to remove the submissional columns without lambda filter, points will be deducted accordingly.

hw_exam_grades.set_index("SID",inplace=True)
columns=filter(lambda x:"Submission" in x,hw_exam_grades.columns)
hw_exam_grades.drop(columns=columns,inplace=True)
hw_exam_grades.head(2)
# Out:
#          First Name Last Name  Homework 1  Homework 1 - Max Points  \
# SID
# axl60952      Aaron    Lester        68.0                       80
# amc28428       Adam    Cooper        80.0                       80
#
#           Homework 2  Homework 2 - Max Points  Homework 3  \
# SID
# axl60952          74                       80          77
# amc28428          78                       80          78
#
#           Homework 3 - Max Points  Homework 4  Homework 4 - Max Points  ...  \
# SID                                                                     ...
# axl60952                       80          89                      100  ...
# amc28428                       80          87                      100  ...
#
#           Homework 9  Homework 9 - Max Points  Homework 10  \
# SID
# axl60952          42                       60           41
# amc28428          45                       60           53
#
#           Homework 10 - Max Points  Exam 1  Exam 1 - Max Points  Exam 2  \
# SID
# axl60952                        60      79                  100      63
# amc28428                        60      65                  100      63
#
#           Exam 2 - Max Points  Exam 3  Exam 3 - Max Points
# SID
# axl60952                  100      68                  100
# amc28428                  100      90                  100
#
# [2 rows x 28 columns]

# %% [markdown]
# ### **Load the Quiz Files**

# %% [markdown]
# Load quiz grades (quiz_1_grades.csv, ..., quiz_5_grades.csv)

# %%
#load all the quizzes now, but i want it the dataframe to be indexed on emails, and return all quizzes corresponding to that email.
#for the expected output of this code, refer to the submissional pdf shared with you in whatsapp group.

quiz1=pd.read_csv("/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv")
quiz2=pd.read_csv()
quiz3=pd.read_csv()
quiz4=pd.read_csv()
quiz5=pd.read_csv()

# %%
quiz_grades = ["/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv","/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv","/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv","/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv","/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv"]
dataframes = []
for i, file in enumerate(quiz_grades):
   df = pd.read_csv(file)
   df.rename(columns={'Grade': f'Quiz {i + 1}'}, inplace=True)
   df = df[['Email', f'Quiz {i + 1}']]
   df.set_index('Email', inplace=True)
   dataframes.append(df)

quizzes = pd.concat(dataframes, axis=1)
quizzes.head()
# Out:
#                           Quiz 1  Quiz 2  Quiz 3  Quiz 4  Quiz 5
# Email
# richard.bennett@univ.edu      10       6       9       8      10
# timothy.parker@univ.edu        9      14      13      14      10
# carol.reyes@univ.edu           5      15       8      14       6
# brooke.powers@univ.edu         6      10      17      10       8
# michael.taylor@univ.edu        5      15      13      12       5

# %% [markdown]
# Now, join the roster and the hw_exam_grades and store it in a df named '**final_df**' display first 5 rows.

# %%
final_df = new_roaster.join(hw_exam_grades)
final_df.head()
# Out:
#                       Email Address  Section First Name Last Name  Homework 1  \
# NetID
# wxb12345  woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# mxl12345   malaika.lambert@univ.edu        2    Malaika   Lambert        63.0
# txj12345       traci.joyce@univ.edu        1      Traci     Joyce         NaN
# jgf12345   john.g.2.flower@univ.edu        3      Gregg    Flower        69.0
# smj00936     stacy.johnson@univ.edu        2      Stacy   Johnson        74.0
#
#           Homework 1 - Max Points  Homework 2  Homework 2 - Max Points  \
# NetID
# wxb12345                       80          62                       80
# mxl12345                       80          57                       80
# txj12345                       80          77                       80
# jgf12345                       80          52                       80
# smj00936                       80          55                       80
#
#           Homework 3  Homework 3 - Max Points  ...  Homework 9  \
# NetID                                          ...
# wxb12345          73                       80  ...          45
# mxl12345          78                       80  ...          45
# txj12345          58                       80  ...          59
# jgf12345          64                       80  ...          42
# smj00936          60                       80  ...          59
#
#           Homework 9 - Max Points  Homework 10  Homework 10 - Max Points  \
# NetID
# wxb12345                       60           46                        60
# mxl12345                       60           37                        60
# txj12345                       60           53                        60
# jgf12345                       60           40                        60
# smj00936                       60           48                        60
#
#           Exam 1  Exam 1 - Max Points  Exam 2  Exam 2 - Max Points  Exam 3  \
# NetID
# wxb12345      86                  100      62                  100      90
# mxl12345      60                  100      91                  100      93
# txj12345     100                  100      84                  100      64
# jgf12345      72                  100      83                  100      77
# smj00936      96                  100      80                  100      86
#
#           Exam 3 - Max Points
# NetID
# wxb12345                  100
# mxl12345                  100
# txj12345                  100
# jgf12345                  100
# smj00936                  100
#
# [5 rows x 30 columns]

# %% [markdown]
# Also, display quiz **columns** and **indexes** in two seperate code blocks to make sure you get the sense of the data.

# %%
final_df.columns
# Out:
# Index(['Email Address', 'Section', 'First Name', 'Last Name', 'Homework 1',
#        'Homework 1 - Max Points', 'Homework 2', 'Homework 2 - Max Points',
#        'Homework 3', 'Homework 3 - Max Points', 'Homework 4',
#        'Homework 4 - Max Points', 'Homework 5', 'Homework 5 - Max Points',
#        'Homework 6', 'Homework 6 - Max Points', 'Homework 7',
#        'Homework 7 - Max Points', 'Homework 8', 'Homework 8 - Max Points',
#        'Homework 9', 'Homework 9 - Max Points', 'Homework 10',
#        'Homework 10 - Max Points', 'Exam 1', 'Exam 1 - Max Points', 'Exam 2',
#        'Exam 2 - Max Points', 'Exam 3', 'Exam 3 - Max Points'],
#       dtype='object')

# %% [markdown]
# ### **Merging the Grade DataFrame**

# %%
#now merge the final_df and quiz grades, on EMAIL ADDRESS and overwrite it in final_df variable
#fill empty values with 0 as well

# %%
if 'Email Address' in final_df.columns:
    final_df.set_index('Email Address', inplace=True)
    final_df = final_df.join(quizes, how='left')
    final_df.head()
final_df.head()
final_df.fillna(0, inplace=True)
final_df.head()
# Out:
#                            Section First Name Last Name  Homework 1  \
# Email Address
# woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# malaika.lambert@univ.edu         2    Malaika   Lambert        63.0
# traci.joyce@univ.edu             1      Traci     Joyce         0.0
# john.g.2.flower@univ.edu         3      Gregg    Flower        69.0
# stacy.johnson@univ.edu           2      Stacy   Johnson        74.0
#
#                            Homework 1 - Max Points  Homework 2  \
# Email Address
# woody.barrera_jr@univ.edu                       80          62
# malaika.lambert@univ.edu                        80          57
# traci.joyce@univ.edu                            80          77
# john.g.2.flower@univ.edu                        80          52
# stacy.johnson@univ.edu                          80          55
#
#                            Homework 2 - Max Points  Homework 3  \
# Email Address
# woody.barrera_jr@univ.edu                       80          73
# malaika.lambert@univ.edu                        80          78
# traci.joyce@univ.edu                            80          58
# john.g.2.flower@univ.edu                        80          64
# stacy.johnson@univ.edu                          80          60
#
#                            Homework 3 - Max Points  Homework 4  ...  \
# Email Address                                                   ...
# woody.barrera_jr@univ.edu                       80          83  ...
# malaika.lambert@univ.edu                        80          83  ...
# traci.joyce@univ.edu                            80          91  ...
# john.g.2.flower@univ.edu                        80          75  ...
# stacy.johnson@univ.edu                          80          67  ...
#
#                            Homework 9  Homework 9 - Max Points  Homework 10  \
# Email Address
# woody.barrera_jr@univ.edu          45                       60           46
# malaika.lambert@univ.edu           45                       60           37
# traci.joyce@univ.edu               59                       60           53
# john.g.2.flower@univ.edu           42                       60           40
# stacy.johnson@univ.edu             59                       60           48
#
#                            Homework 10 - Max Points  Exam 1  \
# Email Address
# woody.barrera_jr@univ.edu                        60      86
# malaika.lambert@univ.edu                         60      60
# traci.joyce@univ.edu                             60     100
# john.g.2.flower@univ.edu                         60      72
# stacy.johnson@univ.edu                           60      96
#
#                            Exam 1 - Max Points  Exam 2  Exam 2 - Max Points  \
# Email Address
# woody.barrera_jr@univ.edu                  100      62                  100
# malaika.lambert@univ.edu                   100      91                  100
# traci.joyce@univ.edu                       100      84                  100
# john.g.2.flower@univ.edu                   100      83                  100
# stacy.johnson@univ.edu                     100      80                  100
#
#                            Exam 3  Exam 3 - Max Points
# Email Address
# woody.barrera_jr@univ.edu      90                  100
# malaika.lambert@univ.edu       93                  100
# traci.joyce@univ.edu           64                  100
# john.g.2.flower@univ.edu       77                  100
# stacy.johnson@univ.edu         86                  100
#
# [5 rows x 29 columns]

# %% [markdown]
# ### **Calculate Grades with Pandas DataFrame**

# %% [markdown]
# ### Exam Grades

# %% [markdown]
# Now, I want you to calculate the percentage of all 3 exams and then have it display at the end of the final_df

# %%
#to find the percentage:   Exam 1 / Exam 1 max points.
final_df['Exam 1 Score'] = final_df['Exam 1'] / final_df['Exam 1 - Max Points']
final_df['Exam 2 Score'] = final_df['Exam 2'] / final_df['Exam 2 - Max Points']
final_df['Exam 3 Score'] = final_df['Exam 3'] / final_df['Exam 3 - Max Points']
final_df.head()
#Hint: you can use fstrings and loops for it
# Out:
#                            Section First Name Last Name  Homework 1  \
# Email Address
# woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# malaika.lambert@univ.edu         2    Malaika   Lambert        63.0
# traci.joyce@univ.edu             1      Traci     Joyce         0.0
# john.g.2.flower@univ.edu         3      Gregg    Flower        69.0
# stacy.johnson@univ.edu           2      Stacy   Johnson        74.0
#
#                            Homework 1 - Max Points  Homework 2  \
# Email Address
# woody.barrera_jr@univ.edu                       80          62
# malaika.lambert@univ.edu                        80          57
# traci.joyce@univ.edu                            80          77
# john.g.2.flower@univ.edu                        80          52
# stacy.johnson@univ.edu                          80          55
#
#                            Homework 2 - Max Points  Homework 3  \
# Email Address
# woody.barrera_jr@univ.edu                       80          73
# malaika.lambert@univ.edu                        80          78
# traci.joyce@univ.edu                            80          58
# john.g.2.flower@univ.edu                        80          64
# stacy.johnson@univ.edu                          80          60
#
#                            Homework 3 - Max Points  Homework 4  ...  \
# Email Address                                                   ...
# woody.barrera_jr@univ.edu                       80          83  ...
# malaika.lambert@univ.edu                        80          83  ...
# traci.joyce@univ.edu                            80          91  ...
# john.g.2.flower@univ.edu                        80          75  ...
# stacy.johnson@univ.edu                          80          67  ...
#
#                            Homework 10 - Max Points  Exam 1  \
# Email Address
# woody.barrera_jr@univ.edu                        60      86
# malaika.lambert@univ.edu                         60      60
# traci.joyce@univ.edu                             60     100
# john.g.2.flower@univ.edu                         60      72
# stacy.johnson@univ.edu                           60      96
#
#                            Exam 1 - Max Points  Exam 2  Exam 2 - Max Points  \
# Email Address
# woody.barrera_jr@univ.edu                  100      62                  100
# malaika.lambert@univ.edu                   100      91                  100
# traci.joyce@univ.edu                       100      84                  100
# john.g.2.flower@univ.edu                   100      83                  100
# stacy.johnson@univ.edu                     100      80                  100
#
#                            Exam 3  Exam 3 - Max Points  Exam 1 Score  \
# Email Address
# woody.barrera_jr@univ.edu      90                  100          0.86
# malaika.lambert@univ.edu       93                  100          0.60
# traci.joyce@univ.edu           64                  100          1.00
# john.g.2.flower@univ.edu       77                  100          0.72
# stacy.johnson@univ.edu         86                  100          0.96
#
#                            Exam 2 Score  Exam 3 Score
# Email Address
# woody.barrera_jr@univ.edu          0.62          0.90
# malaika.lambert@univ.edu           0.91          0.93
# traci.joyce@univ.edu               0.84          0.64
# john.g.2.flower@univ.edu           0.83          0.77
# stacy.johnson@univ.edu             0.80          0.86
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Homework Grades

# %% [markdown]
# **Question 1: Identifying Homework Columns**

# %%
#Identify and separate the columns representing homework scores and their respective maximum points.

# %%
homework_columns = sorted([col for col in final_df.columns if 'Homework' in col and 'Max Points' not in col and 'Homework Score' not in col])
homework_max_columns = sorted([col for col in final_df.columns if 'Homework' in col and 'Max Points' in col])
final_df[homework_columns].shape
# Out:
# (150, 10)

# %% [markdown]
# **Question 2: Calculating Homework Score by Total Method**

# %%
#Calculate the homework scores by summing the actual scores and dividing by the total possible points.
homework_scores_total = final_df[homework_columns].sum(axis=1)
homework_max_total = final_df[homework_max_columns].sum(axis=1)
homework_max_total
# Out:
# Email Address
# woody.barrera_jr@univ.edu    740
# malaika.lambert@univ.edu     740
# traci.joyce@univ.edu         740
# john.g.2.flower@univ.edu     740
# stacy.johnson@univ.edu       740
#                             ...
# paul.johnson@univ.edu        740
# danielle.lee@univ.edu        740
# nicole.edwards@univ.edu      740
# bailey.reyes@univ.edu        740
# joyce.walls@univ.edu         740
# Length: 150, dtype: int64

# %% [markdown]
# **Question 3: Storing Homework Score by Total Method**

# %%
#Add the calculated total homework scores to the DataFrame.
final_df['HW_by_Total'] = homework_scores_total / homework_max_total

# %% [markdown]
# **Question 4: Preparing Data for Average Calculation**

# %%
print("First 5 quiz grades:\n", quiz_grades[:5])
print("\nType of quiz_grades:", type(quiz_grades))
print("\nFull quiz_grades data:\n", quiz_grades)
print("\nFirst 5 rows of all_quizzes:\n", all_quizzes.head())
# column names in all_quizzes
print("\nColumn names in all_quizzes:\n", all_quizzes.columns)
# Out:
# First 5 quiz grades:
#  ['/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv']
#
# Type of quiz_grades: <class 'list'>
#
# Full quiz_grades data:
#  ['/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_1_grades - quiz_1_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_2_grades - quiz_2_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_3_grades - quiz_3_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_4_grades - quiz_4_grades.csv', '/content/drive/MyDrive/DataScience_with_KS/Pandas Work/Pandas Mini Project/quiz_5_grades - quiz_5_grades.csv']
#
# First 5 rows of all_quizzes:
#                            Quiz 1  Quiz 2  Quiz 3  Quiz 4  Quiz 5
# Email
# richard.bennett@univ.edu      10       6       9       8      10
# timothy.parker@univ.edu        9      14      13      14      10
# carol.reyes@univ.edu           5      15       8      14       6
# brooke.powers@univ.edu         6      10      17      10       8
# michael.taylor@univ.edu        5      15      13      12       5
#
# Column names in all_quizzes:
#  Index(['Quiz 1', 'Quiz 2', 'Quiz 3', 'Quiz 4', 'Quiz 5'], dtype='object')

# %% [markdown]
# **Question 5: Calculating Homework Score by Average Method**

# %%
#Calculate the average homework scores by dividing each actual score by its corresponding maximum points, summing these ratios, and then dividing by the number of assignments.
homework_avg_scores = (final_df[homework_columns] / final_df[homework_max_columns].values).mean(axis=1)

homework_avg_scores
# Out:
# Email Address
# woody.barrera_jr@univ.edu    0.799405
# malaika.lambert@univ.edu     0.818944
# traci.joyce@univ.edu         0.785940
# john.g.2.flower@univ.edu     0.765710
# stacy.johnson@univ.edu       0.787742
#                                ...
# paul.johnson@univ.edu        0.733325
# danielle.lee@univ.edu        0.816865
# nicole.edwards@univ.edu      0.841175
# bailey.reyes@univ.edu        0.773690
# joyce.walls@univ.edu         0.745171
# Length: 150, dtype: float64

# %% [markdown]
# **Question 6: Storing Homework Score by Average Method**

# %%
#Add the calculated average homework scores to the DataFrame.
final_df['Hw_by_Average'] = homework_avg_scores

# %% [markdown]
# **Question 7: Determining the Final Homework Score**

# %%
#Determine the final homework score for each student by taking the maximum value between the total and average methods.
final_df['Homework Score'] = final_df[['HW_by_Total', 'Hw_by_Average']].mean(axis=1)
final_df.head()
# Out:
#                            Section First Name Last Name  Homework 1  \
# Email Address
# woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# malaika.lambert@univ.edu         2    Malaika   Lambert        63.0
# traci.joyce@univ.edu             1      Traci     Joyce         0.0
# john.g.2.flower@univ.edu         3      Gregg    Flower        69.0
# stacy.johnson@univ.edu           2      Stacy   Johnson        74.0
#
#                            Homework 1 - Max Points  Homework 2  \
# Email Address
# woody.barrera_jr@univ.edu                       80          62
# malaika.lambert@univ.edu                        80          57
# traci.joyce@univ.edu                            80          77
# john.g.2.flower@univ.edu                        80          52
# stacy.johnson@univ.edu                          80          55
#
#                            Homework 2 - Max Points  Homework 3  \
# Email Address
# woody.barrera_jr@univ.edu                       80          73
# malaika.lambert@univ.edu                        80          78
# traci.joyce@univ.edu                            80          58
# john.g.2.flower@univ.edu                        80          64
# stacy.johnson@univ.edu                          80          60
#
#                            Homework 3 - Max Points  Homework 4  ...  \
# Email Address                                                   ...
# woody.barrera_jr@univ.edu                       80          83  ...
# malaika.lambert@univ.edu                        80          83  ...
# traci.joyce@univ.edu                            80          91  ...
# john.g.2.flower@univ.edu                        80          75  ...
# stacy.johnson@univ.edu                          80          67  ...
#
#                            Exam 2 - Max Points  Exam 3  Exam 3 - Max Points  \
# Email Address
# woody.barrera_jr@univ.edu                  100      90                  100
# malaika.lambert@univ.edu                   100      93                  100
# traci.joyce@univ.edu                       100      64                  100
# john.g.2.flower@univ.edu                   100      77                  100
# stacy.johnson@univ.edu                     100      86                  100
#
#                            Exam 1 Score  Exam 2 Score  Exam 3 Score  \
# Email Address
# woody.barrera_jr@univ.edu          0.86          0.62          0.90
# malaika.lambert@univ.edu           0.60          0.91          0.93
# traci.joyce@univ.edu               1.00          0.84          0.64
# john.g.2.flower@univ.edu           0.72          0.83          0.77
# stacy.johnson@univ.edu             0.96          0.80          0.86
#
#                            HW by Total  Hw_by_Average  HW_by_Total  \
# Email Address
# woody.barrera_jr@univ.edu     0.808108       0.799405     0.808108
# malaika.lambert@univ.edu      0.827027       0.818944     0.827027
# traci.joyce@univ.edu          0.785135       0.785940     0.785135
# john.g.2.flower@univ.edu      0.770270       0.765710     0.770270
# stacy.johnson@univ.edu        0.782432       0.787742     0.782432
#
#                            Homework Score
# Email Address
# woody.barrera_jr@univ.edu        0.803756
# malaika.lambert@univ.edu         0.822986
# traci.joyce@univ.edu             0.785538
# john.g.2.flower@univ.edu         0.767990
# stacy.johnson@univ.edu           0.785087
#
# [5 rows x 36 columns]

# %% [markdown]
# For the output, you may refer to the output refered in the Submission Book.

# %% [markdown]
# ## Quiz Grades
#
# If you used any other method instead of regex to filter the columns, it will result in appropriate points deduction.

# %%
quiz_columns = final_df.filter(regex=r'Quiz \d+$').columns

# %% [markdown]
# 1. Count the number of quizzes.
# 2. Define the maximum possible points for each quiz.
# 3. Compute the quiz score using the total method.
# 4. Compute the quiz score using the average method.
# 5. Determine the final quiz score by taking the maximum of the two methods.
# 6. Display the DataFrame to check the results

# %%
#Expected Output: The DataFrame should contain an additional column 'Quiz Score' showing the final quiz score for each student, calculated as the maximum value between the total and average methods.

# %%
num_quizzes = len(quiz_columns)
max_points_per_quiz = 10
final_df['Quiz Total Score'] = final_df[quiz_columns].sum(axis=1)
final_df['Quiz Average Score'] = final_df[quiz_columns].mean(axis=1) * max_points_per_quiz
final_df['Final Quiz Score'] = final_df[['Quiz Total Score', 'Quiz Average Score']].max(axis=1)

#first few rows of the updated DataFrame
final_df.head()
# Out:
#                            Section First Name Last Name  Homework 1  \
# Email Address
# woody.barrera_jr@univ.edu        1      Woody   Barrera        55.0
# malaika.lambert@univ.edu         2    Malaika   Lambert        63.0
# traci.joyce@univ.edu             1      Traci     Joyce         0.0
# john.g.2.flower@univ.edu         3      Gregg    Flower        69.0
# stacy.johnson@univ.edu           2      Stacy   Johnson        74.0
#
#                            Homework 1 - Max Points  Homework 2  \
# Email Address
# woody.barrera_jr@univ.edu                       80          62
# malaika.lambert@univ.edu                        80          57
# traci.joyce@univ.edu                            80          77
# john.g.2.flower@univ.edu                        80          52
# stacy.johnson@univ.edu                          80          55
#
#                            Homework 2 - Max Points  Homework 3  \
# Email Address
# woody.barrera_jr@univ.edu                       80          73
# malaika.lambert@univ.edu                        80          78
# traci.joyce@univ.edu                            80          58
# john.g.2.flower@univ.edu                        80          64
# stacy.johnson@univ.edu                          80          60
#
#                            Homework 3 - Max Points  Homework 4  ...  \
# Email Address                                                   ...
# woody.barrera_jr@univ.edu                       80          83  ...
# malaika.lambert@univ.edu                        80          83  ...
# traci.joyce@univ.edu                            80          91  ...
# john.g.2.flower@univ.edu                        80          75  ...
# stacy.johnson@univ.edu                          80          67  ...
#
#                            Exam 1 Score  Exam 2 Score  Exam 3 Score  \
# Email Address
# woody.barrera_jr@univ.edu          0.86          0.62          0.90
# malaika.lambert@univ.edu           0.60          0.91          0.93
# traci.joyce@univ.edu               1.00          0.84          0.64
# john.g.2.flower@univ.edu           0.72          0.83          0.77
# stacy.johnson@univ.edu             0.96          0.80          0.86
#
#                            HW by Total  Hw_by_Average  HW_by_Total  \
# Email Address
# woody.barrera_jr@univ.edu     0.808108       0.799405     0.808108
# malaika.lambert@univ.edu      0.827027       0.818944     0.827027
# traci.joyce@univ.edu          0.785135       0.785940     0.785135
# john.g.2.flower@univ.edu      0.770270       0.765710     0.770270
# stacy.johnson@univ.edu        0.782432       0.787742     0.782432
#
#                            Homework Score  Quiz Total Score  \
# Email Address
# woody.barrera_jr@univ.edu        0.803756               0.0
# malaika.lambert@univ.edu         0.822986               0.0
# traci.joyce@univ.edu             0.785538               0.0
# john.g.2.flower@univ.edu         0.767990               0.0
# stacy.johnson@univ.edu           0.785087               0.0
#
#                            Quiz Average Score  Final Quiz Score
# Email Address
# woody.barrera_jr@univ.edu                 NaN               0.0
# malaika.lambert@univ.edu                  NaN               0.0
# traci.joyce@univ.edu                      NaN               0.0
# john.g.2.flower@univ.edu                  NaN               0.0
# stacy.johnson@univ.edu                    NaN               0.0
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Group the data to calculate final scores!

# %%
weights = pd.Series(
    {
        "Exam 1 Score": 0.05,
        "Exam 2 Score": 0.10,
        "Exam 3 Score": 0.15,
        "Quiz Score": 0.30,
        "Homework Score": 0.40,
    }
)

# %% [markdown]
# 1. Define the weights for each component.
# 2. Calculate the final score by applying the weights to each component and summing the results.
# 3. Calculate the ceiling score by rounding up the final score multiplied by 100.
# 4. Define a function to convert numeric scores to letter grades based on standard thresholds.
# 5. Map the ceiling scores to letter grades.
# 6. Store the letter grades as a categorical column in the DataFrame.
# 7. Display the final letter grades.

# %%
#For Expected output, refer to the submissional pdf.
import numpy as np
import pandas as pd

weights = {
    'Quiz': 0.25,
    'Homework': 0.25,
    'Midterm': 0.25,
    'Final': 0.25
}

final_df['Final Score'] = (final_df * pd.Series(weights)).sum(axis=1)

final_df['Ceiling Score'] = np.ceil(final_df['Final Score'] * 100).astype(int)

def score_to_grade(score):
    return (
        'A' if score >= 90 else
        'B' if score >= 80 else
        'C' if score >= 70 else
        'D' if score >= 60 else
        'F'
    )

final_df['Letter Grade'] = final_df['Ceiling Score'].apply(score_to_grade)

final_df['Letter Grade'] = pd.Categorical(
    final_df['Letter Grade'], categories=['F', 'D', 'C', 'B', 'A'], ordered=True
)

print(final_df[['Final Score', 'Ceiling Score', 'Letter Grade']])
# Out:
#                           Final Score  Ceiling Score Letter Grade
# Email Address
# woody.barrera_jr@univ.edu           0              0            F
# malaika.lambert@univ.edu            0              0            F
# traci.joyce@univ.edu                0              0            F
# john.g.2.flower@univ.edu            0              0            F
# stacy.johnson@univ.edu              0              0            F
# ...                               ...            ...          ...
# paul.johnson@univ.edu               0              0            F
# danielle.lee@univ.edu               0              0            F
# nicole.edwards@univ.edu             0              0            F
# bailey.reyes@univ.edu               0              0            F
# joyce.walls@univ.edu                0              0            F
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Now, you have to write the data back to CSV.

# %%
#For the expected output, refer to the submissional pdf
final_df.to_csv('final_grades.csv', index=False)
